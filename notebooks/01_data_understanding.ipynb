# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/raw/itsm_incident_dataset.csv")
df.head()
# Out:
#         Status    Ticket ID  Priority  Source             Topic  \
# 0       Closed  TCKT-100000      High   Email   General Inquiry
# 1       Closed  TCKT-100001      High    Chat     Network Issue
# 2  In Progress  TCKT-100002       Low   Phone   General Inquiry
# 3     Resolved  TCKT-100003  Critical    Chat    Access Request
# 4       Closed  TCKT-100004  Critical  Portal  Hardware Failure
#
#         Agent Group            Agent Name      Created time  \
# 0          Security       Khalid Al-Salem  04-07-2024 12.42
# 1  Customer Service        Ahmed Al-Sabah  23-05-2024 20.03
# 2       Development  Mohammed Al-Mansoori  13-04-2024 20.51
# 3       Development   Mohammed Al-Khalifa  13-05-2024 12.50
# 4  Customer Service      Hassan Al-Nasser  19-06-2024 22.51
#
#   Expected SLA to resolve Expected SLA to first response  ...  \
# 0        04-07-2024 14.42               04-07-2024 13.12  ...
# 1        23-05-2024 22.03               23-05-2024 20.33  ...
# ...

# %%
df.shape
# Out:
# (100000, 22)

# %%
df.columns
# Out:
# Index(['Status', 'Ticket ID', 'Priority', 'Source', 'Topic', 'Agent Group',
#        'Agent Name', 'Created time', 'Expected SLA to resolve',
#        'Expected SLA to first response', 'First response time',
#        'SLA For first response', 'Resolution time', 'SLA For Resolution',
#        'Close time', 'Agent interactions', 'Survey results', 'Product group',
#        'Support Level', 'Country', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of             Status    Ticket ID  Priority  Source             Topic  \
# 0           Closed  TCKT-100000      High   Email   General Inquiry
# 1           Closed  TCKT-100001      High    Chat     Network Issue
# 2      In Progress  TCKT-100002       Low   Phone   General Inquiry
# 3         Resolved  TCKT-100003  Critical    Chat    Access Request
# 4           Closed  TCKT-100004  Critical  Portal  Hardware Failure
# ...            ...          ...       ...     ...               ...
# 99995       Closed  TCKT-199995       Low  Portal     Network Issue
# 99996  In Progress  TCKT-199996    Medium  Portal      Software Bug
# 99997  In Progress  TCKT-199997    Medium    Chat  Hardware Failure
# 99998  In Progress  TCKT-199998      High   Phone  Hardware Failure
# 99999     Resolved  TCKT-199999      High    Chat   General Inquiry
#
#             Agent Group            Agent Name      Created time  \
# ...

# %%
df.describe()
# Out:
#        Agent interactions       Latitude      Longitude
# count       100000.000000  100000.000000  100000.000000
# mean             3.003470      24.002431      53.004252
# std              1.415612       1.156356       1.729986
# min              1.000000      22.000000      50.000000
# 25%              2.000000      22.998075      51.502675
# 50%              3.000000      24.007500      53.005550
# 75%              4.000000      25.000725      54.504500
# max              5.000000      25.999900      55.999900

# %%
df.isnull().sum()
# Out:
# Status                            0
# Ticket ID                         0
# Priority                          0
# Source                            0
# Topic                             0
# Agent Group                       0
# Agent Name                        0
# Created time                      0
# Expected SLA to resolve           0
# Expected SLA to first response    0
# First response time               0
# SLA For first response            0
# Resolution time                   0
# SLA For Resolution                0
# Close time                        0
# Agent interactions                0
# Survey results                    0
# Product group                     0
# Support Level                     0
# Country                           0
# Latitude                          0
# Longitude                         0
# dtype: int64

# %%
df.duplicated(subset="Ticket ID").sum()
# Out:
# np.int64(0)

# %%
df.select_dtypes(include="object").nunique()
# Out:
# Status                                 5
# Ticket ID                         100000
# Priority                               4
# Source                                 4
# Topic                                  5
# Agent Group                            5
# Agent Name                            80
# Created time                       77910
# Expected SLA to resolve            77840
# Expected SLA to first response     78000
# First response time                77901
# SLA For first response                 1
# Resolution time                    78103
# SLA For Resolution                     1
# Close time                         77880
# Survey results                         3
# Product group                          4
# Support Level                          3
# Country                                6
# dtype: int64

# %%
df.sample(5)
# Out:
#             Status    Ticket ID  Priority  Source             Topic  \
# 33900     Resolved  TCKT-133900      High   Email    Access Request
# 95877         Open  TCKT-195877    Medium   Email      Software Bug
# 40229       Closed  TCKT-140229  Critical  Portal  Hardware Failure
# 83676          New  TCKT-183676    Medium  Portal     Network Issue
# 10976  In Progress  TCKT-110976       Low    Chat      Software Bug
#
#             Agent Group          Agent Name      Created time  \
# 33900       Network Ops   Hassan Al-Khalifa   09-05-2024 3.55
# 95877       Development  Yousef Al-Mansoori  26-04-2024 11.17
# 40229       Network Ops      Ali Al-Khalifa  04-08-2024 20.12
# 83676  Customer Service       Saif Al-Sabah   03-04-2024 4.20
# 10976        IT Support   Khalid Al-Khalifa   11-04-2024 8.57
#
#       Expected SLA to resolve Expected SLA to first response  ...  \
# 33900         09-05-2024 5.55                09-05-2024 4.25  ...
# ...
